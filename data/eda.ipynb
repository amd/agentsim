# %%
from src.data import get_sessions_list

print(get_sessions_list())
# Out:
# [{'filepath': 'C:\\Users\\mdokukin\\.claude\\projects\\C--dev-Codebase--archive-claude-conversations\\922b9ae7-429d-4f94-96aa-13536c891426.jsonl', 'id': '922b9ae7-429d-4f94-96aa-13536c891426', 'project': 'C/dev/Codebase/archive/claude/conversations', 'title': 'Review Claude Code history and monitoring tools'}, {'filepath': 'C:\\Users\\mdokukin\\.claude\\projects\\C--dev-Codebase--archive-claude-conversations\\98add938-c3cb-43f4-bf8c-e1edd9f3c1e6.jsonl', 'id': '98add938-c3cb-43f4-bf8c-e1edd9f3c1e6', 'project': 'C/dev/Codebase/archive/claude/conversations', 'title': 'Understand project purpose and functionality'}, {'filepath': 'C:\\Users\\mdokukin\\.claude\\projects\\C--dev-codebase-agent-sim\\c827a1cf-c976-4ba5-9d39-c1137afd4aea.jsonl', 'id': 'c827a1cf-c976-4ba5-9d39-c1137afd4aea', 'project': 'C/dev/codebase/agent/sim', 'title': 'Debug JSON parsing in eda.ipynb'}, {'filepath': 'C:\\Users\\mdokukin\\.claude\\projects\\C--dev-Codebase-amd-timesheet-extension\\f264bd7f-e2cf-4ec8-bdf6-51c
# ...
